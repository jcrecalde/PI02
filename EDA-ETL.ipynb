# %% [markdown]
# EDA

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# En csv utilizados estan todos los csv transformados para luego trabajarlos en POWER BI

# %% [markdown]
# csv seleccionados para comenzar a hacer el EDA

# %%
#Datasets Internet
df1 = pd.read_csv("data\Acceso_a_internet_fijo_por_tecnologia_y_localidad.csv", decimal=',', thousands=".", encoding = 'utf-8') 
df2 = pd.read_csv("data\Internet_Accesos-por-tecnologia.csv", decimal=',', thousands=".", encoding = 'utf-8')
df3 = pd.read_csv("data\AccesosaInternetfijoporvelocidadbajadayprovincia_2791741681960441935.csv", decimal=',', thousands=".", encoding = 'utf-8')
df4 = pd.read_csv("data\ConectividadalserviciodeInternet_2776151681960602650.csv", decimal=',', thousands=".", encoding = 'utf-8') 
df5 = pd.read_csv("data\historico_velocidad_internet.csv", decimal=',', thousands=".", encoding = 'utf-8') 
df6 = pd.read_csv("Csv_utilizados\\Hogares_accesos100.csv", decimal=',', thousands=".", encoding = 'utf-8')
df7 = pd.read_csv("data\Internet_Accesos-por-tecnologia.csv", decimal=',', thousands=".", encoding = 'utf-8') 
df8 = pd.read_csv("Csv_utilizados\mediciones.csv", decimal=',', thousands=".", encoding = 'utf-8') 
df9 = pd.read_csv("Csv_utilizados\conexiones_internet.csv.csv", decimal=',', thousands=".", encoding = 'utf-8') 
df10 = pd.read_csv("Csv_utilizados\ingresos_telefoniaMovil.csv", decimal=',', thousands=".", encoding = 'utf-8') 
df11 = pd.read_csv("Localidades_con_conectividad_internet.csv", decimal=',', thousands=".", encoding = 'utf-8')

# %%
#Datasets telefonia movil 
df12 = pd.read_csv("data\Telefonia_movil.csv", decimal=',', thousands=".", encoding = 'utf-8')
df13 = pd.read_csv("data\Telefonia_movil_ingresos.csv", decimal=',', thousands=".", encoding = 'utf-8') 
df14 = pd.read_csv("data\Telefonia_movil_Accesos.csv", decimal=',', thousands=".", encoding = 'utf-8')

# %%
#Datasets telefonia fija  
df15 = pd.read_csv("Csv_utilizados\\telefonia_fija.csv", decimal=',', thousands=".", encoding = 'utf-8') 
df16 = pd.read_csv("Csv_utilizados\\telefonia_fija_Acceso.csv", decimal=',', thousands=".", encoding = 'utf-8')  
df17 = pd.read_csv("Csv_utilizados//acceso_habitantes_hogares_tf.csv", decimal=',', thousands=".", encoding = 'utf-8')

# %% [markdown]
# Provincia

# %% [markdown]
# Borro la columna Unnamed:13.

# %%
#df = df.drop("Unnamed: 13", axis=1)

# %%
#df.to_csv("Acceso_a_internet_fijo_por_tecnologia_y_localidad.csv", index=False)

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# General en todo el pais

# %% [markdown]
# Información más general sobre el número de accesos de diferentes tecnologías de Internet en todo el país. Este conjunto de datos no se enfoca en la situación específica de cada localidad, sino en el panorama general de acceso a Internet en Argentina.

# %%
df2
# Out:
#      Año  Trimestre     ADSL  Cablemodem  Fibra óptica  Wireless   Otros  \
# 0   2022          3  1395277     6031970       2871541    557110  235230
# 1   2022          2  1468333     5979214       2723285    556243  231609
# 2   2022          1  1533240     6073426       2219533    545814  251996
# 3   2021          4  1657615     5984240       2072236    523107  252596
# 4   2021          3  1950631     5826257       1566048    492415  250190
# 5   2021          2  2018587     5641731       1472246    476968  253552
# 6   2021          1  2175211     5424782       1362976    434548  250455
# 7   2020          4  2213949     5371824       1311199    421554  253036
# 8   2020          3  2263889     5259351       1170879    413259  248821
# 9   2020          2  2295533     5005115       1106725    376667  247016
# 10  2020          1  2299457     4903674       1047817    352333  209145
# 11  2019          4  2414575     4883869        941295    340144  213298
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Año           35 non-null     int64
#  1   Trimestre     35 non-null     int64
#  2   ADSL          35 non-null     int64
#  3   Cablemodem    35 non-null     int64
#  4   Fibra óptica  35 non-null     int64
#  5   Wireless      35 non-null     int64
#  6   Otros         35 non-null     int64
#  7   Total         35 non-null     int64
#  8   Periodo       35 non-null     object
# dtypes: int64(8), object(1)
# memory usage: 2.6+ KB

# %%
df2.isnull().sum()
# Out:
# Año             0
# Trimestre       0
# ADSL            0
# Cablemodem      0
# Fibra óptica    0
# Wireless        0
# Otros           0
# Total           0
# Periodo         0
# dtype: int64

# %%
df2.describe()
# Out:
#                Año  Trimestre          ADSL    Cablemodem  Fibra óptica  \
# count    35.000000  35.000000  3.500000e+01  3.500000e+01  3.500000e+01
# mean   2017.885714   2.457143  3.040425e+06  4.122601e+06  7.390627e+05
# std       2.564135   1.120474  8.354122e+05  1.225277e+06  7.861772e+05
# min    2014.000000   1.000000  1.395277e+06  2.407330e+06  1.391870e+05
# 25%    2016.000000   1.500000  2.279711e+06  2.966749e+06  1.679880e+05
# 50%    2018.000000   2.000000  3.557216e+06  4.038141e+06  2.262850e+05
# 75%    2020.000000   3.000000  3.723156e+06  5.132233e+06  1.138802e+06
# max    2022.000000   4.000000  3.803024e+06  6.073426e+06  2.871541e+06
#
#             Wireless          Otros         Total
# count      35.000000      35.000000  3.500000e+01
# mean   248280.028571  147431.085714  8.297800e+06
# std    174354.292929   85868.716764  1.399611e+06
# min     70749.000000   54300.000000  6.398398e+06
# 25%     85107.500000   62763.500000  7.057455e+06
# ...

# %%
# Creo la figura y el eje
fig, ax = plt.subplots(figsize=(10, 5)) 
# Realizo el gráfico de dispersión
ax.scatter(df2["Fibra óptica"], df2["Año"])  
ax.scatter(df2["Cablemodem"], df2["Año"]) 
ax.scatter(df2["ADSL"], df2["Año"]) 

# Agrego etiquetas y título
ax.set_xlabel("Fibra óptica")
ax.set_ylabel("año")
ax.set_title("Gráfico de dispersión")
plt.show()

# %% [markdown]
# Lo primero que puedo notar que desde el 2014 el numero de personas suscriptas aumento en todos los servicios(ADSL,cablemodem,Fibra optica, Wireles, otros).
#
# El grafico lo utilizo para demostrar que la fibra optica y cable modem son la mas utilizadas. Pero como medio de transmision es mejor fibra optica
#
# Wireless de todas es la tiene menos suscripciones

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# Proporcionaría información sobre el número de hogares conectados a Internet en diferentes regiones del país, importante para  monitorear el progreso del objetivo de aumentar en un 2% el acceso al servicio de Internet.

# %% [markdown]
# Me sirve para calcular la coneccion de internet en 100 hogares (primer kpi)

# %%
df6
# Out:
#       Año  Trimestre            Provincia  Accesos por cada 100 hogares
# 0    2022          3         Buenos Aires                         78.11
# 1    2022          3      Capital Federal                        122.28
# 2    2022          3            Catamarca                         65.33
# 3    2022          3                Chaco                         43.86
# 4    2022          3               Chubut                         84.38
# ..    ...        ...                  ...                           ...
# 835  2014          1           Santa Cruz                         28.94
# 836  2014          1             Santa Fe                         47.85
# 837  2014          1  Santiago Del Estero                         16.31
# 838  2014          1     Tierra Del Fuego                         63.97
# 839  2014          1              Tucumán                         33.42
#
# [840 rows x 4 columns]

# %%
df6.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df6.info()
#
# NameError: name 'df6' is not defined

# %%
df6.describe()
# Out:
#                Año   Trimestre  Accesos por cada 100 hogares
# count   840.000000  840.000000                    840.000000
# mean   2017.885714    2.457143                     49.065750
# std       2.528745    1.105009                     23.151885
# min    2014.000000    1.000000                      9.350000
# 25%    2016.000000    1.000000                     32.107500
# 50%    2018.000000    2.000000                     45.900000
# 75%    2020.000000    3.000000                     61.865000
# max    2022.000000    4.000000                    124.060000

# %% [markdown]
# Como primer analisis es que por cada 100 hogares durante un periodo de tiempo es de 49% lo que indice que aproximadamente la mitad de los hogares en el area geografica tiene acceso a internet.
# La desviacion estandar(std) indica que hay una gran variabilidad en el numero de accesos a internet por hogar en el area geografica.
#
# El 9.3 del min nos indica que muy pocos hogares no tienen acesso a internet.
#
# El valor máximo de 124.06 indica que algunos hogares en el área geográfica tienen un acceso muy alto a internet. Esto podría deberse a varias razones, como por ejemplo una mejor infraestructura de internet.
#
# El percentil 25 indica que el 25% de los hogares tienen un acceso a internet inferior a 32.11, lo que significa que un cuarto de los hogares en el área geográfica tienen un acceso a internet relativamente bajo. Esto podría deberse a factores como la ubicación geográfica.
#
# El percentil 75 indica que el 75% de los hogares tienen un acceso a internet inferior a 61.86, lo que significa que la mayoría de los hogares en el área geográfica tienen un acceso a internet relativamente moderado. Esto podría sugerir que aún hay margen de mejora para mejorar el acceso a internet para los hogares que se encuentran por debajo de este percentil.
#
# Otra observacion que puedo tener es que el acceso a internet a aumentado con el pasar de los años. de 32.107500 a 124.060000

# %%
# agrupo por año y calculo la media de accesos por cada 100 hogares
df6_por_año = df6.groupby("Año")["Accesos por cada 100 hogares"].mean()

# crear el gráfico de barras
ax = df6_por_año.plot(kind='bar', color='blue', alpha=0.5)

# ajustar las etiquetas del gráfico
ax.set_xlabel('Año')
ax.set_ylabel('Accesos por cada 100 hogares')
ax.set_title('Accesos a Internet por Año')

# mostrar el gráfico
plt.show()

# %% [markdown]
# Como se puede ver el 2022 es el año con mayor crecimiento en la region del acceso a internet.

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------

# %% [markdown]
# Información sobre el número de hogares que tienen acceso a Internet de banda ancha fija en diferentes regiones del país, lo que permitiría identificar las áreas con la mayor necesidad de mejora.

# %%
df9["Dial up"].unique()
# Out:
# array(['6.199', '2.145', '1', '5', '904', '68', '4', '22', '- 0', '171',
#        '777', '468', '548', '281', '182', '198', '110', '2', '312', '30',
#        '6.293', '2.163', '927', '74', '0', '172', '786', '471', '553',
#        '290', '185', '204', '115', '313', '6.385', '2.184', '944', '77',
#        '173', '804', '477', '564', '6', '291', '187', '210', '176', '315',
#        '5.184', '1.608', '3', '800', '62', '15', '116', '619', '373',
#        '501', '256', '148', '197', '151', '289', '25', '825', '5.066',
#        '1.390', '55', '13', '615', '137', '5.134', '1.410', '810', '119',
#        '623', '376', '504', '259', '200', '150', '23', '10.119', '3.477',
#        '9', '1.524', '107', '10', '45', '269', '18', '1.322', '1.986',
#        '563', '328', '228', '544', '32', '10.104', '3.443', '1.518',
#        '105', '44', '268', '1.999', '915', '325', '226', '2.056', '227',
#        '229', '10.563', '6.686', '11', '12', '2.426', '94', '48', '244',
# ...

# %%
df9.isnull().sum()
# Out:
# Año                 0
# Trimestre           0
# Provincia           0
# Banda ancha fija    0
# Dial up             2
# Total               0
# dtype: int64

# %%
df9.describe()
# Out:
#                Año   Trimestre  Banda ancha fija         Total
# count   840.000000  840.000000      8.400000e+02  8.400000e+02
# mean   2017.885714    2.457143      3.447674e+05  3.457417e+05
# std       2.528745    1.105009      7.400503e+05  7.419436e+05
# min    2014.000000    1.000000      1.219300e+04  1.255700e+04
# 25%    2016.000000    1.000000      5.192225e+04  5.202975e+04
# 50%    2018.000000    2.000000      1.029360e+05  1.034895e+05
# 75%    2020.000000    3.000000      1.778685e+05  1.779148e+05
# max    2022.000000    4.000000      4.715469e+06  4.721668e+06

# %% [markdown]
# La conclusion que saco de aca en general es que el numero de abonados a banda ancha fija en el mercado ha estado aumentando en promedio a lo largo del tiempo.
#
# La media de abonados a banda ancha fija en estos trimestres es de 344,767, con una desviación estándar de 741,943. El valor mínimo en los datos es de 12,193 abonados, mientras que el valor máximo es de 4,715,469 abonados.

# %%
# Convierto la columna a tipo numérico
df9['Dial up'] = pd.to_numeric(df9['Dial up'], errors='coerce') 
# Reemplazo los valores nulos por ceros
df9['Dial up'].fillna(0, inplace=True) 
#Redondeo los valores y los convierto a enteros
df9['Dial up'] = df9['Dial up'].round().astype(int)

# %%
# Eliminar los puntos de las columnas numéricas y convertirlas a enteros
df9['Banda ancha fija'] = df9['Banda ancha fija']
df9['Dial up'] = df9['Dial up']

# Agrupar los datos por provincia y sumar las conexiones de cada tipo
datos_provincia = df9.groupby('Provincia').sum()[['Banda ancha fija', 'Dial up']]

# Hacer el gráfico de barras
datos_provincia.plot(kind='bar', figsize=(12, 8))
plt.title('Conexiones de banda ancha fija y dial-up por provincia')
plt.xlabel('Provincia')
plt.ylabel('Cantidad de conexiones')
plt.show()

# %% [markdown]
# Como se puede notar dial up ya casi ni se usa a diferencia de banda ancha

# %% [markdown]
# --------------------------------------------------------------------------------------------

# %% [markdown]
# Mi analisis esta dirigido a que la empresa tenga un aumento de un 2% para el proximo trimestre en todos los servicios que brinda.

# %% [markdown]
# Datasets que voy a utilizar para internet

# %%
df8.head(2)
# Out:
#     Año  Trimestre        Provincia  HASTA 512 kbps  + 512 Kbps - 1 Mbps  \
# 0  2022          3     buenos aires           29985                27709
# 1  2022          3  capital federal             517                 5742
#
#    + 1 Mbps - 6 Mbps  + 6 Mbps - 10 Mbps  + 10 Mbps - 20 Mbps  \
# 0             290315              297915               267044
# 1              34371               67829                51946
#
#    + 20 Mbps - 30 Mbps  + 30 Mbps  OtrasMediciones  TotalMediciones
# 0               124190    3618689          65821.0          4721668
# 1                28692    1253105         105477.0          1547679

# %%
df8.info()

# %%
df8.to_csv("mediciones.csv", index=True)

# %%
df6.head()
# Out:
#     Año  Trimestre        Provincia  Accesos por cada 100 hogares
# 0  2022          3     Buenos Aires                         78.11
# 1  2022          3  Capital Federal                        122.28
# 2  2022          3        Catamarca                         65.33
# 3  2022          3            Chaco                         43.86
# 4  2022          3           Chubut                         84.38

# %%
df2.head(2)
# Out:
#     Año  Trimestre     ADSL  Cablemodem  Fibra óptica  Wireless  \
# 0  2022          3  1395277     6031970       2871541    557110
# 1  2022          2  1468333     5979214       2723285    556243
#
#    OtrasTecnologias  TotalTecnologias
# 0            235230          11091128
# 1            231609          10958684

# %%
df2 = df2.rename(columns= {"Total": "TotalTecnologias", "Otros": "OtrasTecnologias"})

# %%
df2.drop("Periodo", axis = 1, inplace = True)

# %%
df2.to_csv("tecnologias_internet.csv", index = True)

# %%
df6['Provincia'] = df6['Provincia'].str.lower().str.strip()
df8['Provincia'] = df8['Provincia'].str.lower().str.strip()

# %% [markdown]
# Aumentar en un 2% el acceso al servicio de internet para el próximo trimestre, cada 100 hogares, por provincia.

# %%
df6.head()
# Out:
#     Año  Trimestre        Provincia  Accesos por cada 100 hogares
# 0  2022          3     Buenos Aires                         78.11
# 1  2022          3  Capital Federal                        122.28
# 2  2022          3        Catamarca                         65.33
# 3  2022          3            Chaco                         43.86
# 4  2022          3           Chubut                         84.38

# %%
df6 = pd.read_csv("Csv_utilizados\\Hogares_accesos100.csv", decimal=',', thousands=".", encoding = 'utf-8')

# %%
df6
# Out:
#       Año  Trimestre            Provincia  Accesos por cada 100 hogares  \
# 0    2022          3         Buenos Aires                         78.11
# 1    2022          3      Capital Federal                        122.28
# 2    2022          3            Catamarca                         65.33
# 3    2022          3                Chaco                         43.86
# 4    2022          3               Chubut                         84.38
# ..    ...        ...                  ...                           ...
# 835  2014          1           Santa Cruz                         28.94
# 836  2014          1             Santa Fe                         47.85
# 837  2014          1  Santiago Del Estero                         16.31
# 838  2014          1     Tierra Del Fuego                         63.97
# 839  2014          1              Tucumán                         33.42
#
#      Accesos por cada 100 hogares trimestre anterior + 2%  Diferencia  \
# ...

# %%
# Creo la figura y el eje
fig, ax = plt.subplots(figsize=(10, 5))

# Realizo el gráfico de dispersión
ax.scatter(df6["Accesos por cada 100 hogares"], df6["Provincia"])

# Agrego etiquetas y título
ax.set_xlabel("Accesos por cada 100 hogares")
ax.set_ylabel("Provincia")
ax.set_title("Gráfico de dispersión")
plt.show()

# %% [markdown]
# Aca podemos ver como se distribuye el acceso a las provincias

# %% [markdown]
# Calculo la diferencia en un trimestre con respecto al anterior

# %%
# Obtengo los valores de accesos por cada 100 hogares en un período anterior
accesos_anterior = df6.groupby(["Provincia"])['Accesos por cada 100 hogares'].shift(-1)
# Calculo el aumento del 2% en el período anterior
aumento = accesos_anterior * 1.02
# Asigno los valores calculados al trimestre siguiente
df6.loc[:, "Accesos por cada 100 hogares trimestre anterior + 2%"] = round(aumento,2)

# %%
#Remplazo los valores nulos por los valores en la fila de la columna acceso por cada 100 hogares 
 
df6["Accesos por cada 100 hogares trimestre anterior + 2%"] = df6["Accesos por cada 100 hogares trimestre anterior + 2%"].fillna(df6["Accesos por cada 100 hogares"])

# %%
#Ahora calculo la difencia 
 
df6["Diferencia"] = round(df6["Accesos por cada 100 hogares trimestre anterior + 2%"] - df6["Accesos por cada 100 hogares"], 2)

# %%
#Luego calculo su porcentaje de firencia 

df6["Porcentaje de diferencia"] = round(df6["Diferencia"] / df6["Accesos por cada 100 hogares"] * 100, 2)

# %%
df6
# Out:
#       Año  Trimestre            Provincia  Accesos por cada 100 hogares  \
# 0    2022          3         Buenos Aires                         78.11
# 1    2022          3      Capital Federal                        122.28
# 2    2022          3            Catamarca                         65.33
# 3    2022          3                Chaco                         43.86
# 4    2022          3               Chubut                         84.38
# ..    ...        ...                  ...                           ...
# 835  2014          1           Santa Cruz                         28.94
# 836  2014          1             Santa Fe                         47.85
# 837  2014          1  Santiago Del Estero                         16.31
# 838  2014          1     Tierra Del Fuego                         63.97
# 839  2014          1              Tucumán                         33.42
#
#      Accesos por cada 100 hogares trimestre anterior + 2%  Diferencia  \
# ...

# %% [markdown]
# Transformo los . a ,

# %%
df6["Accesos por cada 100 hogares"] = df6["Accesos por cada 100 hogares"].apply(lambda x: str(x).replace('.', ',')) 
df6["Accesos por cada 100 hogares trimestre anterior + 2%"] = df6["Accesos por cada 100 hogares trimestre anterior + 2%"].apply(lambda x: str(x).replace('.', ','))  
df6["Diferencia"] = df6["Diferencia"].apply(lambda x: str(x).replace('.', ','))  
df6["Porcentaje de diferencia"] = df6["Porcentaje de diferencia"].apply(lambda x: str(x).replace('.', ','))

# %% [markdown]
# Creo el nuevo csv para graficarlo en power bi

# %%
df6.to_csv("Hogares_accesos100.csv", decimal=",", index=False)

# %% [markdown]
# Creo un dataframe provincias

# %%
provincias = ["Buenos Aires", "Capital federal", "Catamarca", "Chaco", "Chubut", "Cordoba", "Corrientes", "Entre rios", "Formosa", "Jujuy", "La Pampa", "La Rioja",
               "Mendoza", "Misiones", "Neuquen", "Rio Negro", "Salta", "San Juan", "San luis", "Santa Cruz", "Santa Fe", "Santiago Del Estero", "Tierra Del Fuego", "Tucuman"]

# %%
provincias.to_csv('provincias.csv', index=True)

# %%
df9.dtypes
# Out:
# Año                   int64
# Trimestre             int64
# Provincia            object
# Banda ancha fija      int64
# Dial up             float64
# Total                 int64
# dtype: object

# %% [markdown]
# Conexiones a internet

# %%
df9["Dial up"] = pd.to_numeric(df9["Dial up"], errors='coerce')

# %%
#Remplazo los nulos por 0 para convertir a entero 
df9['Dial up'].fillna(0, inplace=True)

# %%
#Ahora la convierto en entero 
df9['Dial up'] = df9['Dial up'].astype(int)

# %%
df9.isnull().sum()
# Out:
# Año                 0
# Trimestre           0
# Provincia           0
# Banda ancha fija    0
# Dial up             0
# Total               0
# dtype: int64

# %%
# Crear la nueva columna "Comparación"
df9['Comparación'] = round(df9['Banda ancha fija'] / df9['Dial up'], 2)

# Redondear las columnas "Banda ancha fija" y "Dial up" a 0 decimales
df9['Banda ancha fija'] = round(df9['Banda ancha fija'], 0)
df9['Dial up'] = round(df9['Dial up'], 0)

# %%
df9
# Out:
#       Año  Trimestre            Provincia  Banda ancha fija  Dial up    Total  \
# 0    2022          3         Buenos Aires           4715469        6  4721668
# 1    2022          3      Capital Federal           1545534        2  1547679
# 2    2022          3            Catamarca             70292        1    70293
# 3    2022          3                Chaco            144141        5   144146
# 4    2022          3               Chubut            164874      904   165778
# ..    ...        ...                  ...               ...      ...      ...
# 835  2014          1           Santa Cruz             26304      460    26764
# 836  2014          1             Santa Fe            506000      612   506612
# 837  2014          1  Santiago Del Estero             37124        9    37133
# 838  2014          1     Tierra Del Fuego             27272      766    28038
# 839  2014          1              Tucumán            129944       88   130032
#
#      Comparación
# ...

# %%
df9.to_csv("conexiones_internet.csv", index=True)

# %%
df9 = pd.read_csv("Csv_utilizados\\conexiones_internet.csv", decimal=',', thousands=".", encoding = 'utf-8')

# %%
# Agrupo los datos por trimestre y calcula la cantidad de conexiones de banda ancha fija
banda_ancha_fija_por_trimestre = df9.groupby("Trimestre")["Banda ancha fija"].sum()

# Creo el gráfico de caja y bigotes
fig, ax = plt.subplots()
ax.boxplot(banda_ancha_fija_por_trimestre, vert=False)

# Agrego etiquetas y título al gráfico
ax.set_xlabel("Cantidad de conexiones de banda ancha fija")
ax.set_ylabel("Trimestre")
ax.set_title("Gráfico de outliers de conexiones de banda ancha fija por trimestre")

# Muestro el gráfico
plt.show()

# %% [markdown]
# Muestro la media el minimo y maximo de banda ancha fija.
#
# La media : 7.4
# min: 6.6
# max: 7.9

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------

# %% [markdown]
# Ahora voy a comenzar a analizar los csv para telefonia movil

# %%
df12
# Out:
#      Año  Trimestre  Accesos por cada 100 hab        Periodo
# 0   2013          1                       154   Ene-Mar 2013
# 1   2013          2                       156   Abr-Jun 2013
# 2   2013          3                       159  Jul-Sept 2013
# 3   2013          4                       159   Oct-Dic 2013
# 4   2014          1                       148   Ene-Mar 2014
# 5   2014          2                       143   Abr-Jun 2014
# 6   2014          3                       143  Jul-Sept 2014
# 7   2014          4                       143   Oct-Dic 2014
# 8   2015          1                       140   Ene-Mar 2015
# 9   2015          2                       139   Abr-Jun 2015
# 10  2015          3                       141  Jul-Sept 2015
# 11  2015          4                       143   Oct-Dic 2015
# 12  2016          1                       142   Ene-Mar 2016
# 13  2016          2                       143   Abr-Jun 2016
# ...

# %%
fig, ax = plt.subplots(figsize=(12, 6))
# Agrupo por año y trimestre y calcular la media de accesos por cada 100 hogares
ano_trimestre_group = df12.groupby(["Año", "Trimestre"]).mean(numeric_only=True)
                                                     
# Genero la gráfica
plt.bar(np.arange(len(ano_trimestre_group)), ano_trimestre_group["Accesos por cada 100 hab"])
# Configuro los ejes y el título de la gráfica
plt.xticks(np.arange(len(ano_trimestre_group)), ano_trimestre_group.index, rotation=90)
plt.ylabel("Accesos por cada 100 hab")
plt.title("Promedio de accesos por año y trimestre")
plt.show()

# %% [markdown]
# Aca se puede observar los accesos por trimestre y año

# %%
#Elimno columna que no voy autilizar  
df12 = df12.drop("Periodo", axis = 1)

# %%
# Obtengo los valores de accesos por cada 100 habitantes en un período anterior
accesos_anterior = df12.groupby(["Año"])['Accesos por cada 100 hab'].shift(-1)

# Calculo el aumento del 2% en el período anterior
aumento = accesos_anterior * 1.02

# Asigno los valores calculados al trimestre siguiente
df12.loc[:, "Accesos por cada 100 hab trimestre anterior + 2%"] = round(aumento, 2)

# Remplazo los valores nulos por los valores en la fila de la columna "Accesos por cada 100 hab"
df12["Accesos por cada 100 hab trimestre anterior + 2%"] = df12["Accesos por cada 100 hab trimestre anterior + 2%"].fillna(df12["Accesos por cada 100 hab"])

# Calculo la diferencia
df12["Diferencia"] = round(df12["Accesos por cada 100 hab trimestre anterior + 2%"] - df12["Accesos por cada 100 hab"], 2)

# Calculo su porcentaje de diferencia
df12["Porcentaje de diferencia"] = round(df12["Diferencia"] / df12["Accesos por cada 100 hab"] * 100, 2)

# %%
df12
# Out:
#      Año  Trimestre  Accesos por cada 100 hab  \
# 0   2013          1                       154
# 1   2013          2                       156
# 2   2013          3                       159
# 3   2013          4                       159
# 4   2014          1                       148
# 5   2014          2                       143
# 6   2014          3                       143
# 7   2014          4                       143
# 8   2015          1                       140
# 9   2015          2                       139
# 10  2015          3                       141
# 11  2015          4                       143
# 12  2016          1                       142
# 13  2016          2                       143
# 14  2016          3                       146
# 15  2016          4                       146
# 16  2017          1                       144
# 17  2017          2                       143
# 18  2017          3                       141
# ...

# %%
df12["Accesos por cada 100 hab"] = df12["Accesos por cada 100 hab"].apply(lambda x: str(x).replace('.', ',')) 
df12["Accesos por cada 100 hab trimestre anterior + 2%"] = df12["Accesos por cada 100 hab trimestre anterior + 2%"].apply(lambda x: str(x).replace('.', ','))  
df12["Diferencia"] = df12["Diferencia"].apply(lambda x: str(x).replace('.', ','))  
df12["Porcentaje de diferencia"] = df12["Porcentaje de diferencia"].apply(lambda x: str(x).replace('.', ','))

# %%
df12.to_csv("acceso_100_habitantes.csv", index = True)

# %%
df13.dtypes
# Out:
# Año                       int64
# Trimestre                 int64
# Ingresos (miles de $)    object
# Periodo                  object
# dtype: object

# %%
#Elimino $ y .
df13["Ingresos (miles de $)"] = df13["Ingresos (miles de $)"].str.replace("$", "").str.replace(".", "")
# Out:
# C:\Users\Bounset\AppData\Local\Temp\ipykernel_11824\2486206837.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df13["Ingresos (miles de $)"] = df13["Ingresos (miles de $)"].str.replace("$", "").str.replace(".", "")

# %%
#Cambio el tipo de dato de ingresos 
 
df13["Ingresos (miles de $)"] = df13["Ingresos (miles de $)"].astype(int)

# %%
#Borro la columna periodo al igual que en los anteriores dataframe
df13.drop("Periodo", axis=1, inplace=True)

# %%
df13
# Out:
#      Año  Trimestre  Ingresos (miles de $)
# 0   2013          1               13135235
# 1   2013          2               13970806
# 2   2013          3               15235659
# 3   2013          4               16218846
# 4   2014          1               15938353
# 5   2014          2               17680972
# 6   2014          3               18976053
# 7   2014          4               20012332
# 8   2015          1               19337342
# 9   2015          2               19945453
# 10  2015          3               21785238
# 11  2015          4               24881967
# 12  2016          1               24763052
# 13  2016          2               25353971
# 14  2016          3               27416177
# 15  2016          4               30143233
# 16  2017          1               31205565
# 17  2017          2               33509264
# 18  2017          3               35711689
# 19  2017          4               38110028
# 20  2018          1               38733946
# ...

# %%
# Agrupar los datos por trimestre y calcular el promedio de ingresos en miles
ingresos_por_trimestre = df10.groupby("Año")["Ingresos (miles de $)"].mean()

# Crear el gráfico de línea
ingresos_por_trimestre.plot(kind="line", figsize=(10, 5))

# Agregar etiquetas y título al gráfico
plt.xlabel("Año")
plt.ylabel("Ingresos (miles de $)")
plt.title("Promedio de ingresos por año")

# Mostrar el gráfico
plt.show()

# %% [markdown]
# Los ingresos por año de telefonia movil estan creciendo

# %%
df13.to_csv("ingresos_telefoniaMovil.csv", index=True)

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# TELEFONIA FIJA

# %%
df17 = pd.read_csv("Csv_utilizados//acceso_habitantes_hogares_tf.csv", decimal=',', thousands=".", encoding = 'utf-8')

# %%
df17
# Out:
#      Unnamed: 0   Año  Trimestre            Provincia  \
# 0             0  2014          1         Buenos Aires
# 1             1  2014          1      Capital Federal
# 2             2  2014          1            Catamarca
# 3             3  2014          1                Chaco
# 4             4  2014          1               Chubut
# ..          ...   ...        ...                  ...
# 835         835  2022          3           Santa Cruz
# 836         836  2022          3             Santa Fe
# 837         837  2022          3  Santiago del Estero
# 838         838  2022          3     Tierra del Fuego
# 839         839  2022          3              Tucumán
#
#      Accesos telefonía fija por cada 100 hab  \
# 0                                      26.72
# 1                                      52.66
# 2                                      10.03
# 3                                       9.09
# 4                                      17.66
# ...

# %%
sns.boxplot(data=df17, y="Accesos telefonía fija por cada 100 hab", x="Año")
# Out:
# <AxesSubplot: xlabel='Año', ylabel='Accesos telefonía fija por cada 100 hab'>

# %% [markdown]
# Los outliers que hay de accesos de telefonia fija por cada 100 hab en cada año

# %%
sns.boxplot(data=df17, y="Accesos telefonía fija por cada 100 hogares", x="Año")
# Out:
# <AxesSubplot: xlabel='Año', ylabel='Accesos telefonía fija por cada 100 hogares'>

# %% [markdown]
# Los outliers que hay de accesos de telefonia fija por cada 100 hogares

# %%
df17.isnull().sum() 
df17.dtypes
# Out:
# Año                                              int64
# Trimestre                                        int64
# Provincia                                       object
# Accesos telefonía fija por cada 100 hab        float64
# Accesos telefonía fija por cada 100 hogares    float64
# dtype: object

# %% [markdown]
# En este caso voy a obtener los valores de accesos por cada 100 habitantes y hogares en un período anterior

# %% [markdown]
# Accesos telefonía fija por cada 100 hab trimestre anterior + 2%

# %%
#Obtengo los valores de accesos por cada 100 habitantes en un período anterior
accesos_anterior = df17.groupby(["Provincia"])['Accesos telefonía fija por cada 100 hab'].shift(-1)
# Calculo el aumento del 2% en el período anterior
aumento = accesos_anterior * 1.02
# Asigno los valores calculados al trimestre siguiente
df17.loc[:, "Accesos telefonía fija por cada 100 hab trimestre anterior + 2%"] = round(aumento,2)

# %%
#Remplazo los valores nulos por los valores en la fila de la columna acceso por cada 100 habitantes 
 
df17["Accesos telefonía fija por cada 100 hab trimestre anterior + 2%"] = df17["Accesos telefonía fija por cada 100 hab trimestre anterior + 2%"].fillna(df17["Accesos telefonía fija por cada 100 hab"])

# %%
#Ahora calculo la difencia  
df17["Diferencia habitantes"] = round(df17["Accesos telefonía fija por cada 100 hab trimestre anterior + 2%"] - df17["Accesos telefonía fija por cada 100 hab"], 2)

# %%
#Luego calculo su porcentaje de firencia 

df17["Porcentaje de diferencia habitantes"] = round(df17["Diferencia habitantes"] / df17["Accesos telefonía fija por cada 100 hab"] * 100, 2)

# %%
df17
# Out:
#       Año  Trimestre            Provincia  \
# 0    2014          1         Buenos Aires
# 1    2014          1      Capital Federal
# 2    2014          1            Catamarca
# 3    2014          1                Chaco
# 4    2014          1               Chubut
# ..    ...        ...                  ...
# 835  2022          3           Santa Cruz
# 836  2022          3             Santa Fe
# 837  2022          3  Santiago del Estero
# 838  2022          3     Tierra del Fuego
# 839  2022          3              Tucumán
#
#      Accesos telefonía fija por cada 100 hab  \
# 0                                      26.72
# 1                                      52.66
# 2                                      10.03
# 3                                       9.09
# 4                                      17.66
# ..                                       ...
# 835                                     5.20
# 836                                    13.58
# ...

# %% [markdown]
# Accesos telefonía fija por cada 100 hogares trimestre anterior 2%

# %%
#Obtengo los valores de accesos por cada 100 hogares en un período anterior
accesos_anterior = df17.groupby(["Provincia"])["Accesos telefonía fija por cada 100 hogares"].shift(-1)
# Calculo el aumento del 2% en el período anterior
aumento = accesos_anterior * 1.02
# Asigno los valores calculados al trimestre siguiente
df17.loc[:, "Accesos telefonía fija por cada 100 hogares trimestre anterior + 2%"] = round(aumento,2)

# %%
#Remplazo los valores nulos por los valores en la fila de la columna acceso por cada 100 hogares 
 
df17["Accesos telefonía fija por cada 100 hogares trimestre anterior + 2%"] = df17["Accesos telefonía fija por cada 100 hogares trimestre anterior + 2%"].fillna(df17["Accesos telefonía fija por cada 100 hogares"])

# %%
df17["Diferencia hogares"] = round(df17["Accesos telefonía fija por cada 100 hogares trimestre anterior + 2%"] - df17["Accesos telefonía fija por cada 100 hogares"], 2)

# %%
df17["Porcentaje de diferencia hogares"] = round(df17["Diferencia hogares"] / df17["Accesos telefonía fija por cada 100 hab"] * 100, 2)

# %%
df17
# Out:
#       Año  Trimestre            Provincia  \
# 0    2014          1         Buenos Aires
# 1    2014          1      Capital Federal
# 2    2014          1            Catamarca
# 3    2014          1                Chaco
# 4    2014          1               Chubut
# ..    ...        ...                  ...
# 835  2022          3           Santa Cruz
# 836  2022          3             Santa Fe
# 837  2022          3  Santiago del Estero
# 838  2022          3     Tierra del Fuego
# 839  2022          3              Tucumán
#
#      Accesos telefonía fija por cada 100 hab  \
# 0                                      26.72
# 1                                      52.66
# 2                                      10.03
# 3                                       9.09
# 4                                      17.66
# ..                                       ...
# 835                                     5.20
# 836                                    13.58
# ...

# %%
df17["Accesos telefonía fija por cada 100 hab"] = df17["Accesos telefonía fija por cada 100 hab"].apply(lambda x: str(x).replace('.', ',')) 
df17["Accesos telefonía fija por cada 100 hogares"] = df17["Accesos telefonía fija por cada 100 hogares"].apply(lambda x: str(x).replace('.', ','))   
df17["Accesos telefonía fija por cada 100 hab trimestre anterior + 2%"] = df17["Accesos telefonía fija por cada 100 hab trimestre anterior + 2%"].apply(lambda x: str(x).replace('.', ','))  
df17["Accesos telefonía fija por cada 100 hogares trimestre anterior + 2%"] = df17["Accesos telefonía fija por cada 100 hogares trimestre anterior + 2%"].apply(lambda x: str(x).replace('.', ',')) 
df17["Diferencia habitantes"] = df17["Diferencia habitantes"].apply(lambda x: str(x).replace('.', ','))    
df17["Diferencia hogares"] = df17["Diferencia hogares"].apply(lambda x: str(x).replace('.', ','))  
df17["Porcentaje de diferencia habitantes"] = df17["Porcentaje de diferencia habitantes"].apply(lambda x: str(x).replace('.', ','))  
df17["Porcentaje de diferencia hogares"] = df17["Porcentaje de diferencia hogares"].apply(lambda x: str(x).replace('.', ','))

# %%
df17.to_csv("acceso_habitantes_hogares_tf.csv", index=True)

# %%
df15 = pd.read_csv("Csv_utilizados\\telefonia_fija.csv", decimal=",", thousands=".", encoding = "utf-8")

# %%
df15.head()
# Out:
#     Año  Trimestre        Provincia  Accesos telefonía fija (total)  \
# 0  2022          3     Buenos Aires                         3422524
# 1  2022          3  Capital Federal                         1675854
# 2  2022          3        Catamarca                           25672
# 3  2022          3            Chaco                           65662
# 4  2022          3           Chubut                           72311
#
#    Accesos telefonía fija (hogares)  Accesos telefonía fija (comercial)  \
# 0                           3129178                              228867
# 1                           1532216                              112066
# 2                             23471                                1717
# 3                             60034                                4391
# 4                             66114                                4835
#
#    Accesos telefonía fija (gobierno)  Accesos telefonía fija (otros)
# ...

# %%
df_grouped = df15.groupby(["Provincia", "Año"]).mean()[["Accesos telefonía fija (hogares)", "Accesos telefonía fija (comercial)", "Accesos telefonía fija (gobierno)", "Accesos telefonía fija (otros)"]]

# %%
df_grouped_by_prov = df_grouped.groupby("Provincia").sum()

# %%
df_grouped_by_prov.plot(kind='bar', figsize=(10, 5))
plt.ylabel("Accesos")
plt.title("Accesos totales de telefonía fija por provincia")
plt.show()

# %% [markdown]
# Como se puede ver la telefonia fija en hogares es mas utilizada pero se esta usando cada ves menos en general

# %%
df15
# Out:
#       Año  Trimestre            Provincia  Accesos telefonía fija (total)  \
# 0    2022          3         Buenos Aires                         3422524
# 1    2022          3      Capital Federal                         1675854
# 2    2022          3            Catamarca                           25672
# 3    2022          3                Chaco                           65662
# 4    2022          3               Chubut                           72311
# ..    ...        ...                  ...                             ...
# 835  2014          1           Santa Cruz                           40625
# 836  2014          1             Santa Fe                          770361
# 837  2014          1  Santiago del Estero                           70717
# 838  2014          1     Tierra del Fuego                           32631
# 839  2014          1              Tucumán                          210917
#
#      Accesos telefonía fija (hogares)  Accesos telefonía fija (comercial)  \
# ...

# %%
sns.boxplot(data=df15, y='Accesos telefonía fija (hogares)', x='Año')
# Out:
# <AxesSubplot: xlabel='Año', ylabel='Accesos telefonía fija (hogares)'>

# %%
año_group = df15.groupby("Año").mean().sort_values("Accesos telefonía fija (hogares)", ascending=False)
año_group.plot(kind='bar', y="Accesos telefonía fija (hogares)", figsize=(10, 5))
plt.ylabel("Accesos telefonía fija (hogares)")
plt.title("Promedio de accesos por Año")
plt.show()
# Out:
# C:\Users\Bounset\AppData\Local\Temp\ipykernel_16636\2237208051.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   año_group = df15.groupby("Año").mean().sort_values("Accesos telefonía fija (hogares)", ascending=False)

# %%
provincia_group = df15('Provincia').mean().sort_values('Accesos telefonía fija por cada 100 hogares', ascending=False)
provincia_group.plot(kind='bar', y='Accesos telefonía fija por cada 100 hogares', figsize=(10, 5))
plt.ylabel('Accesos telefonía fija por cada 100 hogares')
plt.title('Promedio de accesos por provincia')
plt.show()

# %% [markdown]
# En 2016 2017 hubo los accesos mas altos

# %%
df16
# Out:
#       Año  Trimestre            Provincia  \
# 0    2014          1         Buenos Aires
# 1    2014          1      Capital Federal
# 2    2014          1            Catamarca
# 3    2014          1                Chaco
# 4    2014          1               Chubut
# ..    ...        ...                  ...
# 835  2022          3           Santa Cruz
# 836  2022          3             Santa Fe
# 837  2022          3  Santiago del Estero
# 838  2022          3     Tierra del Fuego
# 839  2022          3              Tucumán
#
#      Accesos telefonía fija por cada 100 hab  \
# 0                                       2672
# 1                                       5266
# 2                                       1003
# 3                                        909
# 4                                       1766
# ..                                       ...
# 835                                      520
# 836                                     1358
# ...

# %%
sns.boxplot(data=df16, y="Accesos telefonía fija por cada 100 hab", x="Año")
# Out:
# <AxesSubplot: xlabel='Año', ylabel='Accesos telefonía fija por cada 100 hab'>

# %%
sns.boxplot(data=df16, y="Accesos telefonía fija por cada 100 hogares", x="Año")
# Out:
# <AxesSubplot: xlabel='Año', ylabel='Accesos telefonía fija por cada 100 hogares'>

# %%
provincia_group = df16.groupby("Provincia").mean().sort_values("Accesos telefonía fija por cada 100 hab", ascending=False)
provincia_group.plot(kind='bar', y="Accesos telefonía fija por cada 100 hab", figsize=(10, 5))
plt.ylabel("Accesos telefonía fija por cada 100 hab")
plt.title("romedio de accesos por provincia")
plt.show()

# %%
provincia_group = df16.groupby("Provincia").mean().sort_values("Accesos telefonía fija por cada 100 hogares", ascending=False)
provincia_group.plot(kind="bar", y="Accesos telefonía fija por cada 100 hogares", figsize=(10, 5))
plt.ylabel("Accesos telefonía fija por cada 100 hogares")
plt.title("Promedio de accesos por provincia")
plt.show()

# %% [markdown]
# Muchos mas accesos por hogares!
